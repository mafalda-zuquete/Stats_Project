# %%
import pandas as pd

# %%
df = pd.read_csv('emission_full.csv')
df
# Out:
#      country_name  year  GHG_emissions  CH4_emissions  N2O_emissions  \
# 0     Afghanistan  1990      15.212848       9.311589       2.984055
# 1     Afghanistan  1991      15.286439       9.516187       3.082194
# 2     Afghanistan  1992      14.010531       9.571483       3.041733
# 3     Afghanistan  1993      14.028118       9.609869       3.089066
# 4     Afghanistan  1994      13.985408       9.789039       2.920713
# 5     Afghanistan  1995      14.334937      10.057814       3.047666
# 6     Afghanistan  1996      15.323211      10.864798       3.286952
# 7     Afghanistan  1997      16.284527      11.578103       3.611278
# 8     Afghanistan  1998      17.124436      12.155188       3.921105
# 9     Afghanistan  1999      18.000555      12.950226       4.210406
# 10    Afghanistan  2000      16.496011      12.027926       3.667837
# 11    Afghanistan  2001      15.209422      11.099311       3.250581
# 12    Afghanistan  2002      17.699094      12.767309       3.782143
# ...

# %%
df.columns
# Out:
# Index(['country_name', 'year', 'GHG_emissions', 'CH4_emissions',
#        'N2O_emissions', 'F_Gas_emissions', 'CO2_emissions', 'CH4_emissions.1',
#        'N2O_emissions.1', 'energy_emissions', 'industry_emissions',
#        'agriculture_emissions', 'waste_emissions',
#        'land_use_foresty_emissions', 'bunker_fuels_emissions',
#        'electricity_heat_emissions', 'construction_emissions',
#        'transports_emissions', 'other_fuels_emissions', 'other_emissions',
#        'subregion', 'region-wb', 'continent', 'iso-a3', 'iso-a2'],
#       dtype='object')

# %%
df = df.drop('GHG_emissions','')
